# %% [raw]
# ---
# description: Docker
# output-file: index.html
# skip_exec: true
# skip_showdoc: true
# title: Docker
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## [Ways of setting up Docker container](https://www.youtube.com/watch?v=RUqGlWr5LBA)

# %% [markdown]
# ## [Examples of Docker files](https://docs.techdox.nz/grafana/)

# %% [markdown]
# - [x] Docker Jupyter Labs
# - [x] Docker Firefox
# - [x] portainer
# - [x] Docker kali-linux
# - [x] Docker ubuntu - not working
# - [ ] Docker Nginx
# - [ ] Docker Django
# - [ ] Docker postgresql
# - [ ] Docker Grafana, Prometheus, Influx

# %% [markdown]
# ```sh
# docker compose up --build -d
#
# ```
